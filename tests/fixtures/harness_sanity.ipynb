# %% [markdown]
# # Harness sanity notebook
#
# Minimal fixture for run_notebook tests. Includes markdown so code cell indices are explicit.

# %%
# Code cell 0
import os
harness_sanity_ran = True
status='started'

# %% [markdown]
# ## After code cell 0

# %%
# Code cell 1: file write and a variable only this cell sets
only_in_cell_1 = True
with open("_assets/sanity_out.txt", "w") as f:
    f.write("ok")

# %% [markdown]
# ## After code cell 1

# %%
# Code cell 2
only_in_cell_2 = True
status='finished'
